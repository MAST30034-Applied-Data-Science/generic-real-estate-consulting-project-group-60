# %% [markdown]
# Data preprocessing

# %%
import pandas as pd
import re
house_2022 = pd.read_json('../data/raw/2022_house_data.json')
house_2022=house_2022.T
house_2022[5:10]
# Out:
#                                                                                           name  \
# https://www.domain.com.au/3-27-flinders-lane-me...       3/27 Flinders Lane Melbourne VIC 3000
# https://www.domain.com.au/611-408-lonsdale-stre...  611/408 Lonsdale Street Melbourne VIC 3000
# https://www.domain.com.au/102-9-bligh-place-mel...        102/9 Bligh Place Melbourne VIC 3000
# https://www.domain.com.au/1715-220-spencer-stre...  1715/220 Spencer Street Melbourne VIC 3000
# https://www.domain.com.au/104-300-swanston-stre...  104/300 Swanston Street Melbourne VIC 3000
#
#                                                         cost_text  \
# https://www.domain.com.au/3-27-flinders-lane-me...  $420 per week
# https://www.domain.com.au/611-408-lonsdale-stre...           $350
# https://www.domain.com.au/102-9-bligh-place-mel...           $600
# https://www.domain.com.au/1715-220-spencer-stre...           $600
# https://www.domain.com.au/104-300-swanston-stre...           $550
#
# ...
