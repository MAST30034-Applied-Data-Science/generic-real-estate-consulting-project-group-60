# %% [markdown]
# # Random forest

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import pandas as pd
from sklearn.metrics import r2_score

# %%
# this is the final version of the data set
property_data_2017_2022 = pd.read_csv('../data/raw/2017_2022_house_data_final.csv')
property_data_2023_2025 = pd.read_csv('../data/raw/2023_2025_house_data_final.csv')

# %%
property_data_2023_2025['car'] = property_data_2023_2025['car'].fillna(0)
property_data_2023_2025['bed'] = property_data_2023_2025['bed'].fillna(0)
property_data_2023_2025['bath'] = property_data_2023_2025['bath'].fillna(0)
property_data_2023_2025 = property_data_2023_2025[property_data_2023_2025['real_school_distance'] != 'school_distance_txt']
property_data_2023_2025 = property_data_2023_2025[property_data_2023_2025['real_school_duration'] != 'school_duration_txt']
property_data_2023_2025 = property_data_2023_2025[property_data_2023_2025['real_school_duration'] != 'duration_txt']
property_data_2023_2025 = property_data_2023_2025[property_data_2023_2025['real_station_distance'] != 'station_distance_txt']
property_data_2023_2025 = property_data_2023_2025[property_data_2023_2025['real_station_duration'] != 'station_duration_txt']
property_data_2023_2025 = property_data_2023_2025[property_data_2023_2025['real_station_duration'] != 'duration_txt']
property_data_2017_2022 = property_data_2017_2022[property_data_2017_2022['real_school_distance'] != 'school_distance_txt']
property_data_2017_2022 = property_data_2017_2022[property_data_2017_2022['real_school_duration'] != 'school_duration_txt']
property_data_2017_2022 = property_data_2017_2022[property_data_2017_2022['real_school_duration'] != 'duration_txt']
property_data_2017_2022 = property_data_2017_2022[property_data_2017_2022['real_station_distance'] != 'station_distance_txt']
property_data_2017_2022 = property_data_2017_2022[property_data_2017_2022['real_station_duration'] != 'station_duration_txt']
property_data_2017_2022 = property_data_2017_2022[property_data_2017_2022['real_station_duration'] != 'duration_txt']

# %%
property_data_2023_2025 = property_data_2023_2025.dropna()

# %%
X = property_data_2017_2022[['Population','real_station_distance','real_school_distance','car','Income','bed','bath','Hospital num']]
y = property_data_2017_2022['week_rent']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)
regressor = RandomForestRegressor(n_estimators = 10,random_state = 0)
regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([461. , 420. , 343. , ..., 447. , 329.5, 539.5])

# %%
r2_score(y_test,y_pred)
# Out:
# 0.20161581399340933

# %%
X_future = property_data_2023_2025[['Population','real_station_distance','real_school_distance','car','Income','bed','bath','Hospital num']]

# %%
# predict the future renting fee
y_pred_future = regressor.predict(X_future)

# %%
property_data_2023_2025['week_rent'] = y_pred_future

# %%
property_data_2023_2025[property_data_2023_2025['year']==2023].groupby('closest_sa2').mean('week_rent')
# Out:
#               Unnamed: 0    year     postcode       bed      bath       car  \
# closest_sa2
# Abbotsford        3868.5  2023.0  3067.000000  2.086957  1.391304  0.913043
# Airport West      2934.5  2023.0  3042.000000  2.458333  1.291667  1.208333
# Albert Park       8200.0  2023.0  3206.000000  2.225806  1.451613  0.516129
# Alexandra         9754.5  2023.0  3712.750000  1.500000  1.000000  2.000000
# Alfredton         8912.5  2023.0  3350.047619  3.500000  1.833333  2.023810
# ...                  ...     ...          ...       ...       ...       ...
# Yarram           10529.0  2023.0  3971.000000  2.000000  2.000000  1.000000
# Yarraville        1293.5  2023.0  3013.000000  2.500000  1.333333  1.125000
# Yarrawonga        9780.0  2023.0  3730.000000  3.120000  1.640000  1.880000
# Yarriambiack      9100.5  2023.0  3393.000000  2.250000  0.750000  1.250000
# Yea               9757.5  2023.0  3717.000000  1.500000  0.500000  1.500000
#
# ...

# %%
property_data_2023_2025[property_data_2023_2025['year']==2024].groupby('closest_sa2').mean('week_rent')
# Out:
#               Unnamed: 0    year     postcode       bed      bath       car  \
# closest_sa2
# Abbotsford       14526.5  2024.0  3067.000000  2.086957  1.391304  0.913043
# Airport West     13592.5  2024.0  3042.000000  2.458333  1.291667  1.208333
# Albert Park      18858.0  2024.0  3206.000000  2.225806  1.451613  0.516129
# Alexandra        20412.5  2024.0  3712.750000  1.500000  1.000000  2.000000
# Alfredton        19570.5  2024.0  3350.047619  3.500000  1.833333  2.023810
# ...                  ...     ...          ...       ...       ...       ...
# Yarram           21187.0  2024.0  3971.000000  2.000000  2.000000  1.000000
# Yarraville       11951.5  2024.0  3013.000000  2.500000  1.333333  1.125000
# Yarrawonga       20438.0  2024.0  3730.000000  3.120000  1.640000  1.880000
# Yarriambiack     19758.5  2024.0  3393.000000  2.250000  0.750000  1.250000
# Yea              20415.5  2024.0  3717.000000  1.500000  0.500000  1.500000
#
# ...

# %%
property_data_2023_2025[property_data_2023_2025['year']==2025].groupby('closest_sa2').mean('week_rent')
# Out:
#               Unnamed: 0    year     postcode       bed      bath       car  \
# closest_sa2
# Abbotsford       25184.5  2025.0  3067.000000  2.086957  1.391304  0.913043
# Airport West     24250.5  2025.0  3042.000000  2.458333  1.291667  1.208333
# Albert Park      29516.0  2025.0  3206.000000  2.225806  1.451613  0.516129
# Alexandra        31070.5  2025.0  3712.750000  1.500000  1.000000  2.000000
# Alfredton        30228.5  2025.0  3350.047619  3.500000  1.833333  2.023810
# ...                  ...     ...          ...       ...       ...       ...
# Yarram           31845.0  2025.0  3971.000000  2.000000  2.000000  1.000000
# Yarraville       22609.5  2025.0  3013.000000  2.500000  1.333333  1.125000
# Yarrawonga       31096.0  2025.0  3730.000000  3.120000  1.640000  1.880000
# Yarriambiack     30416.5  2025.0  3393.000000  2.250000  0.750000  1.250000
# Yea              31073.5  2025.0  3717.000000  1.500000  0.500000  1.500000
#
# ...

# %%
test = property_data_2023_2025[property_data_2023_2025['year']==2025].groupby('closest_sa2').mean('week_rent').reset_index()

# %%
#As for the large house so many demand of the house
test[test.closest_sa2 == 'Taylors Lakes']
# Out:
#        closest_sa2  Unnamed: 0    year     postcode       bed      bath  \
# 289  Taylors Lakes     24067.0  2025.0  3037.714286  3.571429  1.857143
#
#           car       Income   Population  real_school_distance  \
# 289  2.428571  74879.47619  18164.08877             65.542857
#
#      real_school_duration  real_station_distance  real_station_duration  \
# 289             45.242857                    3.3               6.585714
#
#      Hospital num
# 289      0.142857

# %%
test[test.closest_sa2 == 'Wheelers Hill']
# Out:
#        closest_sa2  Unnamed: 0    year  postcode       bed      bath  car  \
# 322  Wheelers Hill     27640.0  2025.0    3150.0  3.842105  2.157895  2.0
#
#            Income    Population  real_school_distance  real_school_duration  \
# 322  78893.666667  21752.770952              0.826316              2.431579
#
#      real_station_distance  real_station_duration  Hospital num
# 322               5.078947              10.615789           2.0
